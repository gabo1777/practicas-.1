# %% [markdown]
# <a href="https://colab.research.google.com/github/gabo1777/practicas-.1/blob/main/juego_del_gato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A0=0
A1=0
A2=0
B0=0
B1=0
B2=0
C0=0
C1=0
C2=0
ganar=0

jugador1=input('J1 Ingrese su casilla: ')
if(jugador1=='A0'):
  A0=1
elif(jugador1=='A1'):
  A1=1
elif(jugador1=='A2'):
  A2=1
elif(jugador1=='B0'):
  B0=1
elif(jugador1=='B1'):
  B1=1
elif(jugador1=='B2'):
  B2=1
elif(jugador1=='C0'):
  C0=1
elif(jugador1=='C1'):
  C1=1
elif(jugador1=='C2'):
  C2=1

jugador2=input('J2 Ingrese su casilla: ')
if(jugador2=='A0'):
  A0=2
elif(jugador2=='A1'):
  A1=2
elif(jugador2=='A2'):
  A2=2
elif(jugador2=='B0'):
  B0=2
elif(jugador2=='B1'):
  B1=2
elif(jugador2=='B2'):
  B2=2
elif(jugador2=='C0'):
  C0=2
elif(jugador2=='C1'):
  C1=2
elif(jugador2=='C2'):
  C2=2

jugador1=input('J1 Ingrese su casilla: ')
if(jugador1=='A0'):
  A0=1
elif(jugador1=='A1'):
  A1=1
elif(jugador1=='A2'):
  A2=1
elif(jugador1=='B0'):
  B0=1
elif(jugador1=='B1'):
  B1=1
elif(jugador1=='B2'):
  B2=1
elif(jugador1=='C0'):
  C0=1
elif(jugador1=='C1'):
  C1=1
elif(jugador1=='C2'):
  C2=1

jugador2=input('J2 Ingrese su casilla: ')
if(jugador2=='A0'):
  A0=2
elif(jugador2=='A1'):
  A1=2
elif(jugador2=='A2'):
  A2=2
elif(jugador2=='B0'):
  B0=2
elif(jugador2=='B1'):
  B1=2
elif(jugador2=='B2'):
  B2=2
elif(jugador2=='C0'):
  C0=2
elif(jugador2=='C1'):
  C1=2
elif(jugador2=='C2'):
  C2=2


if(ganar==0):
  jugador1=input('J1 Ingrese su casilla: ')
  if(jugador1=='A0'):
    A0=1
  elif(jugador1=='A1'):
    A1=1
  elif(jugador1=='A2'):
    A2=1
  elif(jugador1=='B0'):
    B0=1
  elif(jugador1=='B1'):
    B1=1
  elif(jugador1=='B2'):
    B2=1
  elif(jugador1=='C0'):
    C0=1
  elif(jugador1=='C1'):
    C1=1
  elif(jugador1=='C2'):
    C2=1
  if((A0==1) and (A1==1)and(A2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((B0==1) and (B1==1)and(B2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((C0==1) and (C1==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A0==1) and (B0==1)and(C0==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A1==1) and (B1==1)and(C1==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A2==1) and (B2==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A0==1) and (B1==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A2==1) and (B1==1)and(C0==1)):
    print("Gana jugador 1")
    ganar=1


if(ganar==0):
  jugador2=input('J2 Ingrese su casilla: ')
  if(jugador2=='A0'):
    A0=2
  elif(jugador2=='A1'):
    A1=2
  elif(jugador2=='A2'):
    A2=2
  elif(jugador2=='B0'):
    B0=2
  elif(jugador2=='B1'):
    B1=2
  elif(jugador2=='B2'):
    B2=2
  elif(jugador2=='C0'):
    C0=2
  elif(jugador2=='C1'):
    C1=2
  elif(jugador2=='C2'):
    C2=2
  if((A0==2) and (A1==2)and(A2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((B0==2) and (B1==2)and(B2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((C0==2) and (C1==2)and(C2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A0==2) and (B0==2)and(C0==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A1==2) and (B1==2)and(C1==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A2==2) and (B2==2)and(C2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A0==2) and (B1==2)and(C2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A2==2) and (B1==2)and(C0==2)):
    print("Gana jugador 2")
    ganar=1
if(ganar==0):    
  jugador1=input('J1 Ingrese su casilla: ')
  if(jugador1=='A0'):
    A0=1
  elif(jugador1=='A1'):
    A1=1
  elif(jugador1=='A2'):
    A2=1
  elif(jugador1=='B0'):
    B0=1
  elif(jugador1=='B1'):
    B1=1
  elif(jugador1=='B2'):
    B2=1
  elif(jugador1=='C0'):
    C0=1
  elif(jugador1=='C1'):
    C1=1
  elif(jugador1=='C2'):
    C2=1
  if((A0==1) and (A1==1)and(A2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((B0==1) and (B1==1)and(B2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((C0==1) and (C1==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A0==1) and (B0==1)and(C0==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A1==1) and (B1==1)and(C1==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A2==1) and (B2==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A0==1) and (B1==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A2==1) and (B1==1)and(C0==1)):
    print("Gana jugador 1")
    ganar=1
if(ganar==0):
  jugador2=input('J2 Ingrese su casilla: ')
  if(jugador2=='A0'):
    A0=2
  elif(jugador2=='A1'):
    A1=2
  elif(jugador2=='A2'):
    A2=2
  elif(jugador2=='B0'):
    B0=2
  elif(jugador2=='B1'):
    B1=2
  elif(jugador2=='B2'):
    B2=2
  elif(jugador2=='C0'):
    C0=2
  elif(jugador2=='C1'):
    C1=2
  elif(jugador2=='C2'):
    C2=2
  if((A0==2) and (A1==2)and(A2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((B0==2) and (B1==2)and(B2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((C0==2) and (C1==2)and(C2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A0==2) and (B0==2)and(C0==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A1==2) and (B1==2)and(C1==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A2==2) and (B2==2)and(C2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A0==2) and (B1==2)and(C2==2)):
    print("Gana jugador 2")
    ganar=1
  elif((A2==2) and (B1==2)and(C0==2)):
    print("Gana jugador 2")
    ganar=1
if(ganar==0):
  jugador1=input('J1 Ingrese su casilla: ')
  if(jugador1=='A0'):
    A0=1
  elif(jugador1=='A1'):
    A1=1
  elif(jugador1=='A2'):
    A2=1
  elif(jugador1=='B0'):
    B0=1
  elif(jugador1=='B1'):
    B1=1
  elif(jugador1=='B2'):
    B2=1
  elif(jugador1=='C0'):
    C0=1
  elif(jugador1=='C1'):
    C1=1
  elif(jugador1=='C2'):
    C2=1
  if((A0==1) and (A1==1)and(A2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((B0==1) and (B1==1)and(B2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((C0==1) and (C1==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A0==1) and (B0==1)and(C0==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A1==1) and (B1==1)and(C1==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A2==1) and (B2==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A0==1) and (B1==1)and(C2==1)):
    print("Gana jugador 1")
    ganar=1
  elif((A2==1) and (B1==1)and(C0==1)):
    print("Gana jugador 1")
    ganar=1
  else:
    print('Empate')
