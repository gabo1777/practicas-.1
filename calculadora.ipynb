# %% [markdown]
# <a href="https://colab.research.google.com/github/gabo1777/practicas-.1/blob/main/calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Eliga la magnitud que deseas hacer conversion: (Seleccione un numero)")
print("Longitud-Presione(0)")
print("Temperatura-Presione(1)")
print("Masa-Presione(2)")
print("Volumen-Presione(3)")
print("Tiempo-Presione(4)")
conv=int(input())
if(conv==0):
    print("Que unidades deseas convertir: (Escriba el numero)")
    print("1.-cm/pulgadas")
    print("2.-pulgadas/cm")
    print("3.-m/pies")
    print("4.-pies/m")
    print("5.-m/pulgadas")
    print("6.-pulgadas/m")
    print("7.-m/millas")
    print("8.-millas/m")
    print("9.-Km/yardas")
    print("10.-yardas/km")
    print("11.-Km/millas")
    print("12.-millas/km")
    coco=int(input())
    if(coco==1):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num/2.54
        print(Num,"cm =",R,"Pulgadas")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==2):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num*2.54
        print(Num,"pulgadas =",R,"cm")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==3):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num*3.281
        print(Num,"m =",R,"pies")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==4):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num/3.281
        print(Num,"pies =",R,"m")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==5):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num*39.37
        print(Num,"m =",R,"pulgadas")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==6):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num/39.37
        print(Num,"pulgadas =",R,"m")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==7):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num/1609
        print(Num,"m =",R,"millas")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==8):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num*1609
        print(Num,"millas =",R,"m")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==9):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num*1094
        print(Num,"Km =",R,"yardas")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==10):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num/1094
        print(Num,"yardas =",R,"km")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==11):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num/1.609
        print(Num,"Km =",R,"millas")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

    elif(coco==12):
        print("Ingrese el dato a convertir: ")
        Num=float(input())
        R=Num*1.609
        print(Num,"millas =",R,"km")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

if(conv==1):
      print("Que unidades deseas convertir: (Escriba el numero)")
      print("1.-celsius/farenheit")
      print("2.-farenheit/celsius")
      print("3.-celsius/kelvin")
      print("4.-kelvin/celsius")
      print("5.-kelvin/farenheit")
      print("6.-farenheit/kelvin")
      coco=int(input())
      if(coco==1):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=(Num*(9/5))+32
        print(Num,"°C =",R,"Farenheit")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==2):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=(Num/(9*5))-32
        print(Num,"Farenheit =",R,"°C")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==3):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num+273.15
        print(Num,"°C =",R,"Kelvin")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==4):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num-273.15
        print(Num,"Kelvin =",R,"°C")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==5):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=((Num-273.15)*(9/5))+32
        print(Num,"Kelvin =",R,"Farenheit")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==6):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=((Num -32)*9/5+273.15)
        print(Num,"Farenheit =",R,"Kelin")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

if(conv==2):
        print("Que unidades deseas convertir: (Escriba el numero)")
        print("1.-Kg/Libras")
        print("2.-Libras/kg")
        print("3.-Gramos/Onzas")
        print("4.-Onzas/Gramos")
        print("5.-Kg/Toneladas")
        print("6.-Toneladas/kg")
        coco=int(input())
        if(coco==1):
            print("Ingresa la cantidad que deseas convertir: ")
            Num=float(input())
            R=Num*2.205
            print(Num,"Kg =",R,"Libras")
            archivo=open("Resultado.txt","a")
            archivo.write("\n")
            archivo.write(str(R))
            archivo.close()

        elif(coco==2):
            print("Ingresa la cantidad que deseas convertir: ")
            Num=float(input())
            R=Num/2.205
            print(Num,"Libras =",R,"Kg")
            archivo=open("Resultado.txt","a")
            archivo.write("\n")
            archivo.write(str(R))
            archivo.close()

        elif(coco==3):
            print("Ingresa la cantidad que deseas convertir: ")
            Num=float(input())
            R=Num/28.35
            print(Num,"g =",R,"Onzas")
            archivo=open("Resultado.txt","a")
            archivo.write("\n")
            archivo.write(str(R))
            archivo.close()

        elif(coco==4):
            print("Ingresa la cantidad que deseas convertir: ")
            Num=float(input())
            R=Num*28.35
            print(Num,"Onzas =",R,"g")
            archivo=open("Resultado.txt","a")
            archivo.write("\n")
            archivo.write(str(R))
            archivo.close()

        elif(coco==5):
            print("Ingresa la cantidad que deseas convertir: ")
            Num=float(input())
            R=Num/1000
            print(Num,"Kg =",R,"Toneladas")
            archivo=open("Resultado.txt","a")
            archivo.write("\n")
            archivo.write(str(R))
            archivo.close()

        elif(coco==6):
            print("Ingresa la cantidad que deseas convertir: ")
            Num=float(input())
            R=Num*1000
            print(Num,"Toneladas =",R,"Kg")
            archivo=open("Resultado.txt","a")
            archivo.write("\n")
            archivo.write(str(R))
            archivo.close()

if(conv==3):
      print("Que unidades deseas convertir: (Escriba el numero)")
      print("1.-litro/galon")
      print("2.-galon/Litro")
      print("3.-m^3/yd^3")
      print("4.-yd^3/m^3")
      print("5.-m^3/pulgada^3")
      print("6.-pulgadas/m^3")
      print("7.-m^3/pies^3")
      print("8.-pies^3/m^3")
      coco=int(input())
      if(coco==1):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num*3.785
        print(Num,"Lt =",R,"Galon")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==2):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num/3.785
        print(Num,"Galon =",R,"Lt")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()


      elif(coco==3):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num*1.308
        print(Num,"m^3 =",R,"Yd^3")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==4):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num/1.308
        print(Num,"Yd^3 =",R,"m^3")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==5):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num/1.308
        print(Num,"m^3 =",R,"pulgada^3")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==6):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num*1.308
        print(Num,"pulgada^3 =",R,"m^3") 
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==7):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num*35.315
        print(Num,"m^3 =",R,"pies^3")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==8):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num/35.315
        print(Num,"pies^3 =",R,"m^3")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

if(conv==4):
      print("Que unidades deseas convertir: (Escriba el numero)")
      print("1.-Horas/Minutos")
      print("2.-Minutos/Horas")
      print("3.-Minutos/Segundos")
      print("4.-Segundos/Minutos")
      print("5.-Segundos/Milisegundos")
      print("6.-milisegundos/segundos")
      coco=int(input())
      if(coco==1):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num*60
        print(Num,"Hrs =",R,"Min")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==2):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num/60
        print(Num,"Min =",R,"Hrs")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==3):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num*60
        print(Num,"Min =",R,"Seg")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==4):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num/60
        print(Num,"Seg =",R,"Min")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()

      elif(coco==5):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num*1000
        print(Num,"Seg =",R,"Miliseg")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()
        
      elif(coco==6):
        print("Ingresa la cantidad que deseas convertir: ")
        Num=float(input())
        R=Num/1000
        print(Num,"Miliseg =",R,"Seg")
        archivo=open("Resultado.txt","a")
        archivo.write("\n")
        archivo.write(str(R))
        archivo.close()
# Out:
# Eliga la magnitud que deseas hacer conversion: (Seleccione un numero)
# Longitud-Presione(0)
# Temperatura-Presione(1)
# Masa-Presione(2)
# Volumen-Presione(3)
# Tiempo-Presione(4)
# 0
# Que unidades deseas convertir: (Escriba el numero)
# 1.-cm/pulgadas
# 2.-pulgadas/cm
# 3.-m/pies
# 4.-pies/m
# 5.-m/pulgadas
# 6.-pulgadas/m
# 7.-m/millas
# 8.-millas/m
# 9.-Km/yardas
# 10.-yardas/km
# 11.-Km/millas
# 12.-millas/km
# 5
# Ingrese el dato a convertir:
# 5
# 5.0 m = 196.85 pulgadas
